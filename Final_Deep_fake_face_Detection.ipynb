# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'test-data:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F4975033%2F8368843%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240509%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240509T200616Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...,training-data:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F4975042%2F8368854%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240509%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240509T200616Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading test-data, 31525870 bytes compressed
# [==================================================] 31525870 bytes downloaded
# Downloaded and uncompressed: test-data
# Downloading training-data, 480056651 bytes compressed
# [==================================================] 480056651 bytes downloaded
# Downloaded and uncompressed: training-data
# Data source import complete.

# %%
import torch
import torchvision
from torchvision import transforms
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
from torch.utils.data import DataLoader, Dataset
import pandas as pd

# %%
df_inputs = pd.read_csv('/kaggle/input/training-data/Final_Processed_video/Final_Processed_video/metadata_Training_Inputs.csv')

# %%
df_inputs['filePath'] = '/kaggle/input/training-data/Final_Processed_video/Final_Processed_video/' + df_inputs['file_name']

# %%
df_inputs
# Out:
#      Unnamed: 0   file_name label  split        original  \
# 0             0  aagfhgtpmv  FAKE  train  vudstovrck.mp4
# 1             2  abarnvbtwb  REAL  train             NaN
# 2             4  abqwwspghj  FAKE  train  qzimuostzz.mp4
# 3             5  acifjvzvpm  FAKE  train  kbvibjhfzo.mp4
# 4             6  acqfdwsrhi  FAKE  train  ccfoszqabv.mp4
# ..          ...         ...   ...    ...             ...
# 317         369  ekcrtigpab  REAL  train             NaN
# 318         373  ellavthztb  REAL  train             NaN
# 319         383  eqnoqyfquo  REAL  train             NaN
# 320         385  erlvuvjsjf  REAL  train             NaN
# 321         398  eudeqjhdfd  REAL  train             NaN
#
#                                               filePath
# 0    /kaggle/input/training-data/Final_Processed_vi...
# 1    /kaggle/input/training-data/Final_Processed_vi...
# 2    /kaggle/input/training-data/Final_Processed_vi...
# 3    /kaggle/input/training-data/Final_Processed_vi...
# 4    /kaggle/input/training-data/Final_Processed_vi...
# ..                                                 ...
# 317  /kaggle/input/training-data/Final_Processed_vi...
# 318  /kaggle/input/training-data/Final_Processed_vi...
# 319  /kaggle/input/training-data/Final_Processed_vi...
# 320  /kaggle/input/training-data/Final_Processed_vi...
# 321  /kaggle/input/training-data/Final_Processed_vi...
#
# [322 rows x 6 columns]

# %%
import os
import shutil
import pandas as pd

# Assuming df is your DataFrame with columns 'foldername', 'label'
# df = pd.read_csv('path_to_your_dataframe.csv')
df = df_inputs

# Create the new dataset folder if it doesn't exist
newdataset_path = '/content/Dataset'
os.makedirs(newdataset_path, exist_ok=True)

# Iterate through each row in the DataFrame
for index, row in df.iterrows():
    foldername = row['filePath']
    label = row['label']
    videoFileName = row['file_name']

    # Define the source and destination paths for the image
    image_path = foldername
    destination_folder = os.path.join(newdataset_path, label)

    # Create the label folder if it doesn't exist inside newdataset
    os.makedirs(destination_folder, exist_ok=True)

    try:
        # Move the images to their respective label folders
        image_files = os.listdir(image_path)
        for image_file in image_files:
            source = os.path.join(image_path, image_file)
            destination = os.path.join(destination_folder,  videoFileName+'_'+ image_file)
            shutil.copy(source, destination)
        print(f'Images from {foldername} moved successfully!')
    except FileNotFoundError:
        print(f'Folder {foldername} not found. Skipping...')
        continue

print('Image processing completed!')
# Out:
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/aagfhgtpmv moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/abarnvbtwb moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/abqwwspghj moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/acifjvzvpm moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/acqfdwsrhi moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/acxnxvbsxk moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/acxwigylke moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/aczrgyricp moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/adohikbdaz moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/adylbeequz moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/aelfnikyqj moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/aelzhcnwgf moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/aettqgevhz moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/aevrfsexku moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/afoovlsmtx moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/agdkmztvby moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/agqphdxmwt moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ahbweevwpv moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ahdbuwqxit moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ahfazfbntc moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ahqqqilsxt moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/aipfdnwpoo moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ajqslcypsw moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ajwpjhrbcv moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/aklqzsddfl moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/aknbdpmgua moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/aknmpoonls moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/akvmwkdyuv moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/akxoopqjqz moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/akzbnazxtz moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/aladcziidp moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/alaijyygdv moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/alninxcyhg moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/altziddtxi moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/alvgwypubw moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/amaivqofda moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/amowujxmzc moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/aneclqfpbt moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/anpuvshzoo moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/aorjvbyxhw moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/apatcsqejh moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/apgjqzkoma moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/apogckdfrz moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/aqpnvjhuzw moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/arkroixhey moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/arlmiizoob moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/arrhsnjqku moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/asaxgevnnp moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/aslsvlvpth moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/asmpfjfzif moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/asvcrfdpnq moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/atkdltyyen moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/atxvxouljq moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/atyntldecu moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/atzdznmder moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/aufmsmnoye moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/augtsuxpzc moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/avfitoutyn moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/avgiuextiz moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/avmjormvsx moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/avnqydkqjj moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/avssvvsdhz moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/avtycwsgyb moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/avywawptfc moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/awhmfnnjih moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/awnwkrqibf moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/awukslzjra moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/axczxisdtb moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/axntxmycwd moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/axoygtekut moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/axwovszumc moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/aybgughjxh moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/aybumesmpk moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ayqvfdhslr moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/aytzyidmgs moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/azpuxunqyo moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/azsmewqghg moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bahdpoesir moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bbhpvrmbse moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bbhtdfuqxq moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bchnbulevv moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bctvsmddgq moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bdbhekrrwo moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bddjdhzfze moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bdgipnyobr moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bdnaqemxmr moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bdxuhamuqx moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/beboztfcme moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bejhvclboh moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/benmsfzfaz moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/beyebyhrph moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bffwsjxghk moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bgaogsjehq moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bggsurpgpr moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bghphrsfxf moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bguwlyazau moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bgvhtpzknn moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bgwmmujlmc moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bhbdugnurr moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bhpwpydzpo moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bhsluedavd moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bilnggbxgu moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bjjbwsqjir moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bjkmjilrxp moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bjsmaqefoi moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bkmdzhfzfh moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bkvetcojbt moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bkwxhglwct moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/blpchvmhxx moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/blzydqdfem moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bmbbkwmxqj moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bmehkyanbj moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bmhvktyiwp moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bmioepcpsx moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bmjmjmbglm moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bmjzrlszhi moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bnbuonyoje moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bndybcqhfr moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bnjcdrfuov moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bntlodcfeg moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bofqajtwve moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/boovltmuwi moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bopqhhalml moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bourlmzsio moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bpapbctoao moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bpxckdzddv moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bqdjzqhcft moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bqeiblbxtl moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bqhtpqmmqp moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bqnymlsayl moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bqqpbzjgup moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bqtuuwzdtr moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/brhalypwoo moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/brvqtabyxj moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bseamdrpbj moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bsfmwclnqy moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/btiysiskpf moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/btjlfpzbdu moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/btjwbtsgln moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/btmsngnqhv moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/btohlidmru moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/btugrnoton moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/btunxncpjh moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/btxlttbpkj moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bulkxhhknf moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bvgwelbeof moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bvzjkezkms moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bweezhfpzp moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bwhlgysghg moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bwipwzzxxu moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bwuwstvsbw moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bxzakyopjf moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bydaidkpdp moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/byijojkdba moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/byofowlkki moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/byqzyxifza moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/byunigvnay moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/byyqectxqa moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/bzythlfnhq moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/caqbrkogkb moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cbbibzcoih moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cbltdtxglo moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ccfoszqabv moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ccmonzqfrz moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cdaxixbosp moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cdbsbdymzd moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cdphtzqrvp moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cepxysienc moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cettndmvzl moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ceymbecxnj moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cfxkpiweqt moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cfyduhpbps moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cglxirfaey moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cgvrgibpfo moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/chtapglbcj moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/chviwxsfhg moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/chzieimrwu moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ciyoudyhly moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cizlkenljw moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ckbdwedgmc moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ckjaibzfxa moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ckkuyewywx moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cknyxaqouy moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cksanfsjhc moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/clihsshdkq moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/clrycekyst moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cmbzllswnl moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cmxcfkrjiv moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cnilkgvfei moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/coadfnerlk moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cobjrlugvp moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/covdcysmbi moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cpjxareypw moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cppdvdejkc moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cprhtltsjp moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cqfugiqupm moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cqhngvpgyi moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cqrskwiqng moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/crezycjqyk moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/crktehraph moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/crzfebnfgb moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cthdnahrkh moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ctpqeykqdp moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cttqtsjvgn moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ctzmavwror moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/curpwogllm moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cuzrgrbvil moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cvaksbpssm moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cwbacdwrzo moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cwrtyzndpx moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cwsbspfzck moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cwwandrkus moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cxfujlvsuw moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cxrfacemmq moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cxttmymlbn moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cyboodqqyr moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cyclgfjdrv moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/cyxlcuyznd moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/czkdanyadc moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dafhtipaml moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dakiztgtnw moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dakqwktlbi moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dbhoxkblzx moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dbhrpizyeq moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dbnygxtwek moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dboxtiehng moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dbtbbhakdv moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dbzcqmxzaj moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dbzpcjntve moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dcamvmuors moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dcuiiorugd moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ddepeddixj moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ddhfabwpuz moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ddjggcasdw moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ddpvuimigj moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ddqccgmtka moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/degpbqvcay moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/deywhkarol moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/deyyistcrd moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dfbpceeaox moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dgmevclvzy moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dgxrqjdomn moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dgzklxjmix moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dhcndnuwta moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dhcselezer moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dhevettufk moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dhjmzhrcav moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dhkwmjxwrn moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/diomeixhrg moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/diopzaywor moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/diqraixiov moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/djvtbgwdcc moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/djxdyjopjd moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dkdwxmtpuo moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dkrvorliqc moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dkuayagnmc moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dkwjwbwgey moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dkzvdrzcnr moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dlpoieqvfb moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dnexlwbcxq moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dnhvalzvrt moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dntkzzzcdh moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dnyvfblxpm moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/doanjploai moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dofusvhnib moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dozyddhild moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dptbnjnkdg moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dptrzdvwpg moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dqppxmoqdl moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dqqtjcryjv moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dqswpjoepo moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dqzreruvje moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/drcyabprvt moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/drgjzlxzxj moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/drsakwyvqv moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/drtbksnpol moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dsdoseflas moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dsgpbgsrdm moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dsjbknkujw moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dsndhujjjb moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dtbpmdqvao moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dtocdfbwca moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dubiroskqn moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dulanfulol moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/duvyaxbzvp moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/duycddgtrl moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/duzuusuajr moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dvakowbgbt moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dwediigjit moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dxbqjxrhin moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dxuliowugt moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dxuplhwvig moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dzieklokdr moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dzqwgqewhu moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dzvyfiarrq moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dzwkmcwkwl moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/dzyuwjkjui moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/eajlrktemq moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ebchwmwayp moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ebebgmtlcu moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ebkzwjgjhq moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ebywfrmhtd moved successfully!
# Images from /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/eckvhdusax moved successfully!
# Folder /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ecnihjlfyt not found. Skipping...
# Folder /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ecujsjhscd not found. Skipping...
# Folder /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ecuvtoltue not found. Skipping...
# Folder /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/eczrseixwq not found. Skipping...
# Folder /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/edyncaijwx not found. Skipping...
# Folder /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/eebrkicpry not found. Skipping...
# Folder /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/eebserckhh not found. Skipping...
# Folder /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/eejswgycjc not found. Skipping...
# Folder /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/eekozbeafq not found. Skipping...
# Folder /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/efwfxwwlbw not found. Skipping...
# Folder /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/eggbjzxnmg not found. Skipping...
# Folder /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/egghxjjmfg not found. Skipping...
# Folder /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ehccixxzoe not found. Skipping...
# Folder /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ehtdtkmmli not found. Skipping...
# Folder /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ekcrtigpab not found. Skipping...
# Folder /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/ellavthztb not found. Skipping...
# Folder /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/eqnoqyfquo not found. Skipping...
# Folder /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/erlvuvjsjf not found. Skipping...
# Folder /kaggle/input/training-data/Final_Processed_video/Final_Processed_video/eudeqjhdfd not found. Skipping...
# Image processing completed!

# %%
df_inputs.head(4)
# Out:
#    Unnamed: 0   file_name label  split        original  \
# 0           0  aagfhgtpmv  FAKE  train  vudstovrck.mp4
# 1           2  abarnvbtwb  REAL  train             NaN
# 2           4  abqwwspghj  FAKE  train  qzimuostzz.mp4
# 3           5  acifjvzvpm  FAKE  train  kbvibjhfzo.mp4
#
#                                             filePath
# 0  /kaggle/input/training-data/Final_Processed_vi...
# 1  /kaggle/input/training-data/Final_Processed_vi...
# 2  /kaggle/input/training-data/Final_Processed_vi...
# 3  /kaggle/input/training-data/Final_Processed_vi...

# %%
# import warnings
# warnings.filterwarnings('ignore')

# %%
model = models.inception_v3(pretrained=True)
num_features = model.fc.in_features
model.fc = nn.Sequential(
    nn.Linear(model.fc.in_features, 10),
    nn.Linear(10, 2)
)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/inception_v3_google-0cc3c7bd.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-0cc3c7bd.pth
# 100%|██████████| 104M/104M [00:01<00:00, 78.1MB/s]

# %%
transform = transforms.Compose([
    transforms.Resize((299, 299)),  # Resize images to a fixed size
    transforms.ToTensor(),           # Convert images to PyTorch tensors
    # Add more transformations as needed
])

# %%
import os

directory = '/content/Dataset/FAKE'
files = os.listdir(directory)

# Filter out files with ".jpg" extension
jpg_files = [file for file in files if file.endswith('.jpg')]

# Delete files with other extensions
for file in files:
    if file not in jpg_files:
        os.remove(os.path.join(directory, file))

# %%
from torchvision.datasets import ImageFolder
train_dataset = ImageFolder(root="/content/Dataset/", transform=transform)
test_dataset = ImageFolder(root="/kaggle/input/training-data/Final_Processed_video/Final_Processed_video", transform=transform)

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %%
os.environ['TORCH_USE_CUDA_DSA']='1'

# %%
# device='cuda'
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
# test_loader = DataLoader(test_dataset, batch_size=32)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

model.to(device)
num_epochs = 10
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for inputs, labels in train_loader:
        # print(inputs.to(device))
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        logits = outputs.logits
        # print(logits)
        # print(labels)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
    epoch_loss = running_loss / len(train_loader.dataset)
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}")
# Out:
# Epoch 1/10, Loss: 0.1083
# Epoch 2/10, Loss: 0.0363
# Epoch 3/10, Loss: 0.0253
# Epoch 4/10, Loss: 0.0177
# Epoch 5/10, Loss: 0.0128
# Epoch 6/10, Loss: 0.0107
# Epoch 7/10, Loss: 0.0112
# Epoch 8/10, Loss: 0.0094
# Epoch 9/10, Loss: 0.0060
# Epoch 10/10, Loss: 0.0077

# %%
# !zip -r /kaggle/working/Fake.zip /kaggle/working/FAKE
# !zip -r /kaggle/working/Real.zip /kaggle/working/REAL

torch.save(model.state_dict(), 'model_weights.pth')

# %%
model.eval()  # Switch to evaluation mode
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in test_dataset:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.logits, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_accuracy = correct / total
print(f"Accuracy : {test_accuracy:.2f}")
# Out:
# Accuracy : 95.41
